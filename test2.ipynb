# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
df = pd.read_csv('/content/Bridebook - DS - challengeData.1634399212.csv')
df.head(11)
# Out:
#     userId        regTime  testVariant  primaryAccount regPage   device   app  \
# 0        0  1612810000000            0            True       /  Android  True
# 1        1  1612110000000            1            True       /  Android  True
# 2        2  1612480000000            2            True       /   iPhone  True
# 3        3  1612680000000            1            True       /   iPhone  True
# 4        4  1613010000000            0            True       /  Android  True
# 5        5  1611960000000            0            True       /     iPad  True
# 6        6  1612180000000            2            True       /   iPhone  True
# 7        7  1612200000000            0            True       /  Android  True
# 8        8  1612550000000            0            True       /  Android  True
# 9        9  1612980000000            1            True       /   iPhone  True
# 10      10  1612290000000            2            True       /   iPhone  True
#
#           browser  browserVersion  screenHeight  ...  addedGuestCount  \
# 0          Chrome            77.0           823  ...             True
# 1          Chrome            76.0           732  ...             True
# 2   Mobile Safari             NaN           812  ...             True
# 3   Mobile Safari             NaN           667  ...             True
# 4          Chrome            77.0           740  ...            False
# 5   Mobile Safari             NaN          1024  ...             True
# 6   Mobile Safari             NaN           736  ...            False
# 7          Chrome            76.0           869  ...            False
# 8          Chrome            76.0           780  ...             True
# 9   Mobile Safari             NaN           736  ...             True
# 10  Mobile Safari             NaN           667  ...            False
#
#    addedBudget invitedCollaborator  addedNames finOnb  searchCTA  venEnq  \
# 0         True               False        True      1          0       0
# 1         True               False        True      1          0       0
# 2        False                True        True      1          1       1
# 3         True                True        True      1          1       0
# 4         True               False        True      1          0       0
# 5         True               False        True      1          1       0
# 6        False               False        True      1          0       0
# 7         True               False        True      1          0       0
# 8         True                True        True      1          0       0
# 9         True                True        True      1          1       1
# 10       False                True        True      1          1       0
#
#     venSearch  venViews  sessions
# 0           0         0         6
# 1           0         0         2
# 2          14        16         1
# 3           4         4         3
# 4           0         0         1
# 5           3         0         1
# 6           0         0         1
# 7           0         0         1
# 8           0         0         1
# 9           2         1         2
# 10          6         7         6
#
# [11 rows x 25 columns]

# %% [markdown]
# # **EDA:Exploratory Data Analysis**

# %%
rows = len(df.axes[0])
cols = len(df.axes[1])
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  1051
# Number of Columns:  25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051 entries, 0 to 1050
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   userId               1051 non-null   int64
#  1   regTime              1051 non-null   int64
#  2   testVariant          1051 non-null   int64
#  3   primaryAccount       1051 non-null   bool
#  4   regPage              1051 non-null   object
#  5   device               1051 non-null   object
#  6   app                  1051 non-null   bool
#  7   browser              1051 non-null   object
#  8   browserVersion       409 non-null    float64
#  9   screenHeight         1051 non-null   int64
#  10  screenWidth          1051 non-null   int64
#  11  authMethod           1051 non-null   object
#  12  locationStep         1051 non-null   object
#  13  addedCity            1051 non-null   int64
#  14  locationCountry      442 non-null    object
#  15  addedGuestCount      1051 non-null   bool
#  16  addedBudget          1051 non-null   bool
#  17  invitedCollaborator  1051 non-null   bool
#  18  addedNames           1051 non-null   bool
#  19  finOnb               1051 non-null   int64
#  20  searchCTA            1051 non-null   int64
#  21  venEnq               1051 non-null   int64
#  22  venSearch            1051 non-null   int64
#  23  venViews             1051 non-null   int64
#  24  sessions             1051 non-null   int64
# dtypes: bool(6), float64(1), int64(12), object(6)
# memory usage: 162.3+ KB

# %%
df.describe()
# Out:
#             userId       regTime  testVariant  browserVersion  screenHeight  \
# count  1051.000000  1.051000e+03  1051.000000      409.000000   1051.000000
# mean    661.509990  1.612531e+12     0.600381       76.655257    766.986679
# std     322.209593  3.455717e+08     0.747160        0.734966    116.937459
# min       0.000000  1.611910e+12     0.000000       70.000000    424.000000
# 25%     409.500000  1.612260e+12     0.000000       76.000000    667.000000
# 50%     672.000000  1.612550e+12     0.000000       77.000000    740.000000
# 75%     934.500000  1.612845e+12     1.000000       77.000000    846.000000
# max    1197.000000  1.613090e+12     2.000000       77.000000   1366.000000
#
#        screenWidth    addedCity       finOnb    searchCTA       venEnq  \
# count  1051.000000  1051.000000  1051.000000  1051.000000  1051.000000
# mean    401.732636     0.384396     0.915319     0.466223     0.871551
# std      98.457783     0.486684     0.278539     0.499095     2.625817
# min     320.000000     0.000000     0.000000     0.000000     0.000000
# 25%     360.000000     0.000000     1.000000     0.000000     0.000000
# 50%     375.000000     0.000000     1.000000     0.000000     0.000000
# 75%     414.000000     1.000000     1.000000     1.000000     0.000000
# max    1280.000000     1.000000     1.000000     1.000000    26.000000
#
#          venSearch     venViews     sessions
# count  1051.000000  1051.000000  1051.000000
# mean      5.079924     5.049477     3.367269
# std      10.025552    11.576225     3.696618
# min       0.000000     0.000000     1.000000
# 25%       0.000000     0.000000     1.000000
# 50%       1.000000     0.000000     2.000000
# 75%       6.000000     5.000000     4.000000
# max      92.000000   130.000000    28.000000

# %%
p = df.hist(figsize = (20,20))

# %%
df.isna().sum()
# Out:
# userId                   0
# regTime                  0
# testVariant              0
# primaryAccount           0
# regPage                  0
# device                   0
# app                      0
# browser                  0
# browserVersion         642
# screenHeight             0
# screenWidth              0
# authMethod               0
# locationStep             0
# addedCity                0
# locationCountry        609
# addedGuestCount          0
# addedBudget              0
# invitedCollaborator      0
# addedNames               0
# finOnb                   0
# searchCTA                0
# venEnq                   0
# venSearch                0
# venViews                 0
# sessions                 0
# dtype: int64

# %%
df.corr()['testVariant'].sort_values()
# Out:
# sessions              -0.063704
# venEnq                -0.029101
# app                   -0.028630
# screenWidth           -0.021805
# addedGuestCount       -0.020201
# userId                -0.008726
# screenHeight          -0.007887
# primaryAccount        -0.005040
# venViews              -0.004208
# venSearch              0.002234
# addedNames             0.010597
# finOnb                 0.020291
# invitedCollaborator    0.028060
# addedBudget            0.034372
# searchCTA              0.042941
# browserVersion         0.074665
# addedCity              0.090218
# regTime                0.255130
# testVariant            1.000000
# Name: testVariant, dtype: float64

# %%
plt.figure(figsize=(13,5))  # on this line I just set the size of figure to 12 by 10.
sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')
# Out:
# <Axes: >

# %%
df.apply(lambda x: x.nunique())
# Out:
# userId                 1051
# regTime                 108
# testVariant               3
# primaryAccount            2
# regPage                   3
# device                    3
# app                       2
# browser                   2
# browserVersion            7
# screenHeight             43
# screenWidth              17
# authMethod                3
# locationStep              4
# addedCity                 2
# locationCountry           7
# addedGuestCount           2
# addedBudget               2
# invitedCollaborator       2
# addedNames                2
# finOnb                    2
# searchCTA                 2
# venEnq                   22
# venSearch                52
# venViews                 57
# sessions                 22
# dtype: int64

# %%
df.isnull().sum()
# Out:
# userId                   0
# regTime                  0
# testVariant              0
# primaryAccount           0
# regPage                  0
# device                   0
# app                      0
# browser                  0
# browserVersion         642
# screenHeight             0
# screenWidth              0
# authMethod               0
# locationStep             0
# addedCity                0
# locationCountry        609
# addedGuestCount          0
# addedBudget              0
# invitedCollaborator      0
# addedNames               0
# finOnb                   0
# searchCTA                0
# venEnq                   0
# venSearch                0
# venViews                 0
# sessions                 0
# dtype: int64

# %%
df.groupby(['testVariant','finOnb']).agg({'finOnb': lambda x: x.value_counts()})
# Out:
#                     finOnb
# testVariant finOnb
# 0           0           51
#             1          536
# 1           0           27
#             1          270
# 2           0           11
#             1          156

# %%
df.groupby(['testVariant']).agg({'finOnb': 'mean'})
# Out:
#                finOnb
# testVariant
# 0            0.913118
# 1            0.909091
# 2            0.934132

# %%
df.groupby(['testVariant','searchCTA']).agg({'searchCTA': lambda x: x.value_counts()})
# Out:
#                        searchCTA
# testVariant searchCTA
# 0           0                321
#             1                266
# 1           0                160
#             1                137
# 2           0                 80
#             1                 87

# %%
df.groupby(['testVariant']).agg({'searchCTA': 'mean'})
# Out:
#              searchCTA
# testVariant
# 0             0.453152
# 1             0.461279
# 2             0.520958

# %%
df.groupby(['testVariant']).agg({'venEnq': 'mean'})
# Out:
#                venEnq
# testVariant
# 0            0.921635
# 1            0.875421
# 2            0.688623

# %%
df.groupby(['testVariant']).agg({'venSearch': 'mean'})
# Out:
#              venSearch
# testVariant
# 0             5.287905
# 1             4.198653
# 2             5.916168

# %%
df.groupby(['testVariant']).agg({'venViews': 'mean'})
# Out:
#              venViews
# testVariant
# 0            5.318569
# 1            4.114478
# 2            5.766467

# %%
df.groupby(['testVariant']).agg({'sessions': 'mean'})
# Out:
#              sessions
# testVariant
# 0            3.684838
# 1            2.734007
# 2            3.377246

# %%
#pd.DataFrame(df.loc[:,'testVariant'].value_counts(normalize = True) * 100)

# %% [markdown]
# # ***AB Test***

# %% [markdown]
# Hypothesis
# H0: There is not statistically significant difference between the old page and new page
#
# H1: There is statistically significant difference between the old page and new page:

# %%
import statsmodels.stats.api as sms
from scipy.stats import shapiro, levene, mannwhitneyu

import warnings
warnings.filterwarnings('ignore')

# %%
control = df[df['testVariant'] == 0]

# %%
test_stat, pvalue = shapiro(control['finOnb'])
print('Test Stat = %.3f, p-value = %.50f' % (test_stat, pvalue))
# Out:
# Test Stat = 0.315, p-value = 0.00000000000000000000000000000000000000000594010419

# %%
one = df[df['testVariant'] == 1]

# %%
test_stat, pvalue = shapiro(one['finOnb'])
print('Test Stat = %.13f, p-value = %.50f' % (test_stat, pvalue))
# Out:
# Test Stat = 0.3237064480782, p-value = 0.00000000000000000000000000000012799715834267619283

# %%
two = df[df['testVariant'] == 2]

# %%
test_stat, pvalue = shapiro(two['finOnb'])
print('Test Stat = %.4f, p-value = %.50f' % (test_stat, pvalue))
# Out:
# Test Stat = 0.2668, p-value = 0.00000000000000000000000021651564512380995512384901

# %%
test_stat, pvalue = shapiro(df.loc[df["testVariant"] == 1, "finOnb"])
print("p-value:",pvalue)
print("test_stat:",test_stat)
# Out:
# p-value: 1.279971583426762e-31
# test_stat: 0.3237064480781555

# %%
test_stat, pvalue = shapiro(df.loc[df["testVariant"] == 2, "finOnb"])
print("p-value:",pvalue)
print("test_stat:",test_stat)
# Out:
# p-value: 2.1651564512380996e-25
# test_stat: 0.26684004068374634

# %%
test_stat, pvalue = shapiro(df.loc[df["testVariant"] == 0, "finOnb"])
print("p-value:",pvalue)
print("test_stat:",test_stat)
# Out:
# p-value: 5.9401041902729e-42
# test_stat: 0.31522947549819946
